# %%
from pymongo import MongoClient
import pandas as pd 
from datetime import datetime

# %%
client = MongoClient ("mongodb://root:rootpass@localhost:27017")
print(client.server_info()['version'])
db = client["clinica_veterinaria"]
# Out:
# 8.2.6

# %%
colecao_atendimentos = db["atendimentos"]
colecao_relatorios = db["relatorios"]

# %%
dados = [
{"tutor":"Ana","animal":"Cachorro","nome_pet":"Rex1","servico":"Consulta","valor":120,"cidade":"Assis","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Bruno","animal":"Gato","nome_pet":"Mimi2","servico":"Vacinação","valor":95,"cidade":"Assis","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Carlos","animal":"Cachorro","nome_pet":"Thor3","servico":"Banho","valor":60,"cidade":"Assis","data":datetime(2026,3,3),"forma_pagamento":"Dinheiro"},
{"tutor":"Daniela","animal":"Ave","nome_pet":"Piu4","servico":"Exame","valor":180,"cidade":"Assis","data":datetime(2026,3,4),"forma_pagamento":"Cartão"},
{"tutor":"Eduardo","animal":"Gato","nome_pet":"Luna5","servico":"Consulta","valor":130,"cidade":"Assis","data":datetime(2026,3,5),"forma_pagamento":"Pix"},
{"tutor":"Fernanda","animal":"Cachorro","nome_pet":"Bob6","servico":"Vacinação","valor":90,"cidade":"Assis","data":datetime(2026,3,6),"forma_pagamento":"Dinheiro"},
{"tutor":"Gabriel","animal":"Coelho","nome_pet":"Pompom7","servico":"Consulta","valor":110,"cidade":"Assis","data":datetime(2026,3,7),"forma_pagamento":"Pix"},
{"tutor":"Helena","animal":"Cachorro","nome_pet":"Mel8","servico":"Cirurgia","valor":820,"cidade":"Assis","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Igor","animal":"Gato","nome_pet":"Simba9","servico":"Banho","valor":55,"cidade":"Assis","data":datetime(2026,3,9),"forma_pagamento":"Cartão"},
{"tutor":"Juliana","animal":"Cachorro","nome_pet":"Nina10","servico":"Consulta","valor":125,"cidade":"Assis","data":datetime(2026,3,10),"forma_pagamento":"Pix"},
{"tutor":"Lucas","animal":"Ave","nome_pet":"Sky11","servico":"Exame","valor":200,"cidade":"Assis","data":datetime(2026,3,11),"forma_pagamento":"Cartão"},
{"tutor":"Mariana","animal":"Gato","nome_pet":"Lili12","servico":"Consulta","valor":135,"cidade":"Assis","data":datetime(2026,3,12),"forma_pagamento":"Pix"},
{"tutor":"Nicolas","animal":"Cachorro","nome_pet":"Bolt13","servico":"Vacinação","valor":100,"cidade":"Assis","data":datetime(2026,3,13),"forma_pagamento":"Dinheiro"},
{"tutor":"Patricia","animal":"Cachorro","nome_pet":"Max14","servico":"Consulta","valor":140,"cidade":"Ourinhos","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Rafael","animal":"Gato","nome_pet":"Mia15","servico":"Banho","valor":65,"cidade":"Ourinhos","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Sofia","animal":"Cachorro","nome_pet":"Luna16","servico":"Cirurgia","valor":900,"cidade":"Ourinhos","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Thiago","animal":"Ave","nome_pet":"Blue17","servico":"Exame","valor":170,"cidade":"Ourinhos","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Vanessa","animal":"Gato","nome_pet":"Nino18","servico":"Consulta","valor":125,"cidade":"Ourinhos","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"William","animal":"Cachorro","nome_pet":"Thor19","servico":"Vacinação","valor":95,"cidade":"Ourinhos","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Beatriz","animal":"Coelho","nome_pet":"Fluffy20","servico":"Consulta","valor":115,"cidade":"Ourinhos","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Caio","animal":"Cachorro","nome_pet":"Spike21","servico":"Banho","valor":70,"cidade":"Ourinhos","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Diego","animal":"Gato","nome_pet":"Tom22","servico":"Consulta","valor":135,"cidade":"Ourinhos","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Elisa","animal":"Cachorro","nome_pet":"Mel23","servico":"Exame","valor":210,"cidade":"Ourinhos","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Felipe","animal":"Ave","nome_pet":"Kiwi24","servico":"Consulta","valor":120,"cidade":"Ourinhos","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Gisele","animal":"Gato","nome_pet":"Nina25","servico":"Vacinação","valor":85,"cidade":"Ourinhos","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Hugo","animal":"Cachorro","nome_pet":"Rex26","servico":"Consulta","valor":150,"cidade":"Ourinhos","data":datetime(2026,3,13),"forma_pagamento":"Cartão"},
{"tutor":"Iris","animal":"Cachorro","nome_pet":"Bob27","servico":"Consulta","valor":110,"cidade":"Pompeia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Joao","animal":"Gato","nome_pet":"Luna28","servico":"Banho","valor":60,"cidade":"Pompeia","data":datetime(2026,3,2),"forma_pagamento":"Dinheiro"},
{"tutor":"Karen","animal":"Cachorro","nome_pet":"Thor29","servico":"Cirurgia","valor":780,"cidade":"Pompeia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Leo","animal":"Ave","nome_pet":"Sky30","servico":"Exame","valor":160,"cidade":"Pompeia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Marta","animal":"Gato","nome_pet":"Mimi31","servico":"Consulta","valor":120,"cidade":"Pompeia","data":datetime(2026,3,5),"forma_pagamento":"Cartão"},
{"tutor":"Nelson","animal":"Cachorro","nome_pet":"Max32","servico":"Vacinação","valor":90,"cidade":"Pompeia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Olga","animal":"Coelho","nome_pet":"Pompom33","servico":"Consulta","valor":105,"cidade":"Pompeia","data":datetime(2026,3,7),"forma_pagamento":"Dinheiro"},
{"tutor":"Paulo","animal":"Cachorro","nome_pet":"Bolt34","servico":"Banho","valor":75,"cidade":"Pompeia","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Quezia","animal":"Gato","nome_pet":"Simba35","servico":"Consulta","valor":130,"cidade":"Pompeia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Renato","animal":"Cachorro","nome_pet":"Nina36","servico":"Exame","valor":190,"cidade":"Pompeia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Sara","animal":"Ave","nome_pet":"Blue37","servico":"Consulta","valor":115,"cidade":"Pompeia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Tiago","animal":"Gato","nome_pet":"Lili38","servico":"Vacinação","valor":85,"cidade":"Pompeia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Ursula","animal":"Cachorro","nome_pet":"Rex39","servico":"Consulta","valor":145,"cidade":"Marilia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Vitor","animal":"Gato","nome_pet":"Mia40","servico":"Banho","valor":70,"cidade":"Marilia","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Wesley","animal":"Cachorro","nome_pet":"Thor41","servico":"Cirurgia","valor":870,"cidade":"Marilia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Xuxa","animal":"Ave","nome_pet":"Piu42","servico":"Exame","valor":175,"cidade":"Marilia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Yara","animal":"Gato","nome_pet":"Luna43","servico":"Consulta","valor":135,"cidade":"Marilia","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"Zeca","animal":"Cachorro","nome_pet":"Bob44","servico":"Vacinação","valor":100,"cidade":"Marilia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Aline","animal":"Coelho","nome_pet":"Fluffy45","servico":"Consulta","valor":120,"cidade":"Marilia","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Bruna","animal":"Cachorro","nome_pet":"Spike46","servico":"Banho","valor":80,"cidade":"Marilia","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Cesar","animal":"Gato","nome_pet":"Tom47","servico":"Consulta","valor":140,"cidade":"Marilia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Dora","animal":"Cachorro","nome_pet":"Mel48","servico":"Exame","valor":220,"cidade":"Marilia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Enzo","animal":"Ave","nome_pet":"Kiwi49","servico":"Consulta","valor":130,"cidade":"Marilia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Fabio","animal":"Gato","nome_pet":"Nina50","servico":"Vacinação","valor":90,"cidade":"Marilia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
]

# %%
colecao_atendimentos.delete_many({})
colecao_atendimentos.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69c3352877052eee5d133133'), ObjectId('69c3352877052eee5d133134'), ObjectId('69c3352877052eee5d133135'), ObjectId('69c3352877052eee5d133136'), ObjectId('69c3352877052eee5d133137'), ObjectId('69c3352877052eee5d133138'), ObjectId('69c3352877052eee5d133139'), ObjectId('69c3352877052eee5d13313a'), ObjectId('69c3352877052eee5d13313b'), ObjectId('69c3352877052eee5d13313c'), ObjectId('69c3352877052eee5d13313d'), ObjectId('69c3352877052eee5d13313e'), ObjectId('69c3352877052eee5d13313f'), ObjectId('69c3352877052eee5d133140'), ObjectId('69c3352877052eee5d133141'), ObjectId('69c3352877052eee5d133142'), ObjectId('69c3352877052eee5d133143'), ObjectId('69c3352877052eee5d133144'), ObjectId('69c3352877052eee5d133145'), ObjectId('69c3352877052eee5d133146'), ObjectId('69c3352877052eee5d133147'), ObjectId('69c3352877052eee5d133148'), ObjectId('69c3352877052eee5d133149'), ObjectId('69c3352877052eee5d13314a'), ObjectId('69c3352877052eee5d13314b'), ObjectId('69c3352877052eee5d13314c'), ObjectId('69c3352877052eee5d13314d'), ObjectId('69c3352877052eee5d13314e'), ObjectId('69c3352877052eee5d13314f'), ObjectId('69c3352877052eee5d133150'), ObjectId('69c3352877052eee5d133151'), ObjectId('69c3352877052eee5d133152'), ObjectId('69c3352877052eee5d133153'), ObjectId('69c3352877052eee5d133154'), ObjectId('69c3352877052eee5d133155'), ObjectId('69c3352877052eee5d133156'), ObjectId('69c3352877052eee5d133157'), ObjectId('69c3352877052eee5d133158'), ObjectId('69c3352877052eee5d133159'), ObjectId('69c3352877052eee5d13315a'), ObjectId('69c3352877052eee5d13315b'), ObjectId('69c3352877052eee5d13315c'), ObjectId('69c3352877052eee5d13315d'), ObjectId('69c3352877052eee5d13315e'), ObjectId('69c3352877052eee5d13315f'), ObjectId('69c3352877052eee5d133160'), ObjectId('69c3352877052eee5d133161'), ObjectId('69c3352877052eee5d133162'), ObjectId('69c3352877052eee5d133163'), ObjectId('69c3352877052eee5d133164')], acknowledged=True)

# %%
consulta_valor = list(
    colecao_atendimentos.find(
        {"valor": {"$gte": 90, "$lte": 200}},
        {"_id": 0}
    ))

print("Atendimentos com valor entre 90 e 200:")
for item in consulta_valor:
    print(item)
# Out:
# Atendimentos com valor entre 90 e 200:
# {'tutor': 'Ana', 'animal': 'Cachorro', 'nome_pet': 'Rex1', 'servico': 'Consulta', 'valor': 120, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 1, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Bruno', 'animal': 'Gato', 'nome_pet': 'Mimi2', 'servico': 'Vacinação', 'valor': 95, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 2, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Daniela', 'animal': 'Ave', 'nome_pet': 'Piu4', 'servico': 'Exame', 'valor': 180, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 4, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Eduardo', 'animal': 'Gato', 'nome_pet': 'Luna5', 'servico': 'Consulta', 'valor': 130, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 5, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Fernanda', 'animal': 'Cachorro', 'nome_pet': 'Bob6', 'servico': 'Vacinação', 'valor': 90, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 6, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Gabriel', 'animal': 'Coelho', 'nome_pet': 'Pompom7', 'servico': 'Consulta', 'valor': 110, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 7, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Juliana', 'animal': 'Cachorro', 'nome_pet': 'Nina10', 'servico': 'Consulta', 'valor': 125, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 10, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Lucas', 'animal': 'Ave', 'nome_pet': 'Sky11', 'servico': 'Exame', 'valor': 200, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 11, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Mariana', 'animal': 'Gato', 'nome_pet': 'Lili12', 'servico': 'Consulta', 'valor': 135, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 12, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Nicolas', 'animal': 'Cachorro', 'nome_pet': 'Bolt13', 'servico': 'Vacinação', 'valor': 100, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 13, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Patricia', 'animal': 'Cachorro', 'nome_pet': 'Max14', 'servico': 'Consulta', 'valor': 140, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 1, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Thiago', 'animal': 'Ave', 'nome_pet': 'Blue17', 'servico': 'Exame', 'valor': 170, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 4, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Vanessa', 'animal': 'Gato', 'nome_pet': 'Nino18', 'servico': 'Consulta', 'valor': 125, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 5, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'William', 'animal': 'Cachorro', 'nome_pet': 'Thor19', 'servico': 'Vacinação', 'valor': 95, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 6, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Beatriz', 'animal': 'Coelho', 'nome_pet': 'Fluffy20', 'servico': 'Consulta', 'valor': 115, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 7, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Diego', 'animal': 'Gato', 'nome_pet': 'Tom22', 'servico': 'Consulta', 'valor': 135, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 9, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Felipe', 'animal': 'Ave', 'nome_pet': 'Kiwi24', 'servico': 'Consulta', 'valor': 120, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 11, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Hugo', 'animal': 'Cachorro', 'nome_pet': 'Rex26', 'servico': 'Consulta', 'valor': 150, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 13, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Iris', 'animal': 'Cachorro', 'nome_pet': 'Bob27', 'servico': 'Consulta', 'valor': 110, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 1, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Leo', 'animal': 'Ave', 'nome_pet': 'Sky30', 'servico': 'Exame', 'valor': 160, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 4, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Marta', 'animal': 'Gato', 'nome_pet': 'Mimi31', 'servico': 'Consulta', 'valor': 120, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 5, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Nelson', 'animal': 'Cachorro', 'nome_pet': 'Max32', 'servico': 'Vacinação', 'valor': 90, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 6, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Olga', 'animal': 'Coelho', 'nome_pet': 'Pompom33', 'servico': 'Consulta', 'valor': 105, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 7, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Quezia', 'animal': 'Gato', 'nome_pet': 'Simba35', 'servico': 'Consulta', 'valor': 130, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 9, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Renato', 'animal': 'Cachorro', 'nome_pet': 'Nina36', 'servico': 'Exame', 'valor': 190, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 10, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Sara', 'animal': 'Ave', 'nome_pet': 'Blue37', 'servico': 'Consulta', 'valor': 115, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 11, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Ursula', 'animal': 'Cachorro', 'nome_pet': 'Rex39', 'servico': 'Consulta', 'valor': 145, 'cidade': 'Marilia', 'data': datetime.datetime(2026, 3, 1, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Xuxa', 'animal': 'Ave', 'nome_pet': 'Piu42', 'servico': 'Exame', 'valor': 175, 'cidade': 'Marilia', 'data': datetime.datetime(2026, 3, 4, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Yara', 'animal': 'Gato', 'nome_pet': 'Luna43', 'servico': 'Consulta', 'valor': 135, 'cidade': 'Marilia', 'data': datetime.datetime(2026, 3, 5, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Zeca', 'animal': 'Cachorro', 'nome_pet': 'Bob44', 'servico': 'Vacinação', 'valor': 100, 'cidade': 'Marilia', 'data': datetime.datetime(2026, 3, 6, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Aline', 'animal': 'Coelho', 'nome_pet': 'Fluffy45', 'servico': 'Consulta', 'valor': 120, 'cidade': 'Marilia', 'data': datetime.datetime(2026, 3, 7, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Cesar', 'animal': 'Gato', 'nome_pet': 'Tom47', 'servico': 'Consulta', 'valor': 140, 'cidade': 'Marilia', 'data': datetime.datetime(2026, 3, 9, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Enzo', 'animal': 'Ave', 'nome_pet': 'Kiwi49', 'servico': 'Consulta', 'valor': 130, 'cidade': 'Marilia', 'data': datetime.datetime(2026, 3, 11, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Fabio', 'animal': 'Gato', 'nome_pet': 'Nina50', 'servico': 'Vacinação', 'valor': 90, 'cidade': 'Marilia', 'data': datetime.datetime(2026, 3, 12, 0, 0), 'forma_pagamento': 'Dinheiro'}

# %%
cidades = ["Assis", "Ourinhos", "Pompeia", "Marília"]
consulta_cidades = list(
    colecao_atendimentos.find(
        {"cidade": {"$in": cidades}},
        {"_id": 0}
    ))

print("\nAtendimentos das cidades específicas:")
for item in consulta_cidades:
    print(item)
# Out:
# Atendimentos das cidades específicas:
# {'tutor': 'Ana', 'animal': 'Cachorro', 'nome_pet': 'Rex1', 'servico': 'Consulta', 'valor': 120, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 1, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Bruno', 'animal': 'Gato', 'nome_pet': 'Mimi2', 'servico': 'Vacinação', 'valor': 95, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 2, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Carlos', 'animal': 'Cachorro', 'nome_pet': 'Thor3', 'servico': 'Banho', 'valor': 60, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 3, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Daniela', 'animal': 'Ave', 'nome_pet': 'Piu4', 'servico': 'Exame', 'valor': 180, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 4, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Eduardo', 'animal': 'Gato', 'nome_pet': 'Luna5', 'servico': 'Consulta', 'valor': 130, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 5, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Fernanda', 'animal': 'Cachorro', 'nome_pet': 'Bob6', 'servico': 'Vacinação', 'valor': 90, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 6, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Gabriel', 'animal': 'Coelho', 'nome_pet': 'Pompom7', 'servico': 'Consulta', 'valor': 110, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 7, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Helena', 'animal': 'Cachorro', 'nome_pet': 'Mel8', 'servico': 'Cirurgia', 'valor': 820, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 8, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Igor', 'animal': 'Gato', 'nome_pet': 'Simba9', 'servico': 'Banho', 'valor': 55, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 9, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Juliana', 'animal': 'Cachorro', 'nome_pet': 'Nina10', 'servico': 'Consulta', 'valor': 125, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 10, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Lucas', 'animal': 'Ave', 'nome_pet': 'Sky11', 'servico': 'Exame', 'valor': 200, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 11, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Mariana', 'animal': 'Gato', 'nome_pet': 'Lili12', 'servico': 'Consulta', 'valor': 135, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 12, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Nicolas', 'animal': 'Cachorro', 'nome_pet': 'Bolt13', 'servico': 'Vacinação', 'valor': 100, 'cidade': 'Assis', 'data': datetime.datetime(2026, 3, 13, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Patricia', 'animal': 'Cachorro', 'nome_pet': 'Max14', 'servico': 'Consulta', 'valor': 140, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 1, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Rafael', 'animal': 'Gato', 'nome_pet': 'Mia15', 'servico': 'Banho', 'valor': 65, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 2, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Sofia', 'animal': 'Cachorro', 'nome_pet': 'Luna16', 'servico': 'Cirurgia', 'valor': 900, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 3, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Thiago', 'animal': 'Ave', 'nome_pet': 'Blue17', 'servico': 'Exame', 'valor': 170, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 4, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Vanessa', 'animal': 'Gato', 'nome_pet': 'Nino18', 'servico': 'Consulta', 'valor': 125, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 5, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'William', 'animal': 'Cachorro', 'nome_pet': 'Thor19', 'servico': 'Vacinação', 'valor': 95, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 6, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Beatriz', 'animal': 'Coelho', 'nome_pet': 'Fluffy20', 'servico': 'Consulta', 'valor': 115, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 7, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Caio', 'animal': 'Cachorro', 'nome_pet': 'Spike21', 'servico': 'Banho', 'valor': 70, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 8, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Diego', 'animal': 'Gato', 'nome_pet': 'Tom22', 'servico': 'Consulta', 'valor': 135, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 9, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Elisa', 'animal': 'Cachorro', 'nome_pet': 'Mel23', 'servico': 'Exame', 'valor': 210, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 10, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Felipe', 'animal': 'Ave', 'nome_pet': 'Kiwi24', 'servico': 'Consulta', 'valor': 120, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 11, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Gisele', 'animal': 'Gato', 'nome_pet': 'Nina25', 'servico': 'Vacinação', 'valor': 85, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 12, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Hugo', 'animal': 'Cachorro', 'nome_pet': 'Rex26', 'servico': 'Consulta', 'valor': 150, 'cidade': 'Ourinhos', 'data': datetime.datetime(2026, 3, 13, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Iris', 'animal': 'Cachorro', 'nome_pet': 'Bob27', 'servico': 'Consulta', 'valor': 110, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 1, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Joao', 'animal': 'Gato', 'nome_pet': 'Luna28', 'servico': 'Banho', 'valor': 60, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 2, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Karen', 'animal': 'Cachorro', 'nome_pet': 'Thor29', 'servico': 'Cirurgia', 'valor': 780, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 3, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Leo', 'animal': 'Ave', 'nome_pet': 'Sky30', 'servico': 'Exame', 'valor': 160, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 4, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Marta', 'animal': 'Gato', 'nome_pet': 'Mimi31', 'servico': 'Consulta', 'valor': 120, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 5, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Nelson', 'animal': 'Cachorro', 'nome_pet': 'Max32', 'servico': 'Vacinação', 'valor': 90, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 6, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Olga', 'animal': 'Coelho', 'nome_pet': 'Pompom33', 'servico': 'Consulta', 'valor': 105, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 7, 0, 0), 'forma_pagamento': 'Dinheiro'}
# {'tutor': 'Paulo', 'animal': 'Cachorro', 'nome_pet': 'Bolt34', 'servico': 'Banho', 'valor': 75, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 8, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Quezia', 'animal': 'Gato', 'nome_pet': 'Simba35', 'servico': 'Consulta', 'valor': 130, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 9, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Renato', 'animal': 'Cachorro', 'nome_pet': 'Nina36', 'servico': 'Exame', 'valor': 190, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 10, 0, 0), 'forma_pagamento': 'Cartão'}
# {'tutor': 'Sara', 'animal': 'Ave', 'nome_pet': 'Blue37', 'servico': 'Consulta', 'valor': 115, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 11, 0, 0), 'forma_pagamento': 'Pix'}
# {'tutor': 'Tiago', 'animal': 'Gato', 'nome_pet': 'Lili38', 'servico': 'Vacinação', 'valor': 85, 'cidade': 'Pompeia', 'data': datetime.datetime(2026, 3, 12, 0, 0), 'forma_pagamento': 'Dinheiro'}

# %%
df = pd.DataFrame(consulta_cidades)

print("\nDataFrame:")
print(df.head())
# Out:
# DataFrame:
#      tutor    animal nome_pet    servico  valor cidade       data  \
# 0      Ana  Cachorro     Rex1   Consulta    120  Assis 2026-03-01
# 1    Bruno      Gato    Mimi2  Vacinação     95  Assis 2026-03-02
# 2   Carlos  Cachorro    Thor3      Banho     60  Assis 2026-03-03
# 3  Daniela       Ave     Piu4      Exame    180  Assis 2026-03-04
# 4  Eduardo      Gato    Luna5   Consulta    130  Assis 2026-03-05
#
#   forma_pagamento
# 0             Pix
# 1          Cartão
# 2        Dinheiro
# 3          Cartão
# 4             Pix

# %%
print("\nValores nulos por coluna:")
print(df.isnull().sum())
# Out:
# Valores nulos por coluna:
# tutor              0
# animal             0
# nome_pet           0
# servico            0
# valor              0
# cidade             0
# data               0
# forma_pagamento    0
# dtype: int64

# %%
faturamento_total = float(df["valor"].sum())

faturamento_por_cidade = (
    df.groupby("cidade")["valor"]
    .sum()
    .astype(float)
    .to_dict())

faturamento_por_servico = (
    df.groupby("servico")["valor"]
    .sum()
    .astype(float)
    .to_dict())

ticket_medio_geral = float(df["valor"].mean())

ticket_medio_por_cidade = (
    df.groupby("cidade")["valor"]
    .mean()
    .astype(float)
    .to_dict())

servico_mais_lucrativo = (
    df.groupby("servico")["valor"]
    .sum()
    .idxmax())

cidade_maior_faturamento = (
    df.groupby("cidade")["valor"]
    .sum()
    .idxmax())

top_3_atendimentos = (
    df.sort_values(by="valor", ascending=False)
    .head(3)
    .to_dict(orient="records"))

# %%
relatorio = {
    "data_geracao": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "faturamento_total": faturamento_total,
    "faturamento_por_cidade": faturamento_por_cidade,
    "faturamento_por_servico": faturamento_por_servico,
    "ticket_medio_geral": ticket_medio_geral,
    "ticket_medio_por_cidade": ticket_medio_por_cidade,
    "servico_mais_lucrativo": servico_mais_lucrativo,
    "cidade_maior_faturamento": cidade_maior_faturamento,
    "top_3_atendimentos": top_3_atendimentos
}

print("\nRelatório gerado:")
print(relatorio)
# Out:
# Relatório gerado:
# {'data_geracao': '2026-03-25 01:08:03', 'faturamento_total': 6620.0, 'faturamento_por_cidade': {'Assis': 2220.0, 'Ourinhos': 2380.0, 'Pompeia': 2020.0}, 'faturamento_por_servico': {'Banho': 385.0, 'Cirurgia': 2500.0, 'Consulta': 1985.0, 'Exame': 1110.0, 'Vacinação': 640.0}, 'ticket_medio_geral': 174.21052631578948, 'ticket_medio_por_cidade': {'Assis': 170.76923076923077, 'Ourinhos': 183.07692307692307, 'Pompeia': 168.33333333333334}, 'servico_mais_lucrativo': 'Cirurgia', 'cidade_maior_faturamento': 'Ourinhos', 'top_3_atendimentos': [{'tutor': 'Sofia', 'animal': 'Cachorro', 'nome_pet': 'Luna16', 'servico': 'Cirurgia', 'valor': 900, 'cidade': 'Ourinhos', 'data': Timestamp('2026-03-03 00:00:00'), 'forma_pagamento': 'Cartão'}, {'tutor': 'Helena', 'animal': 'Cachorro', 'nome_pet': 'Mel8', 'servico': 'Cirurgia', 'valor': 820, 'cidade': 'Assis', 'data': Timestamp('2026-03-08 00:00:00'), 'forma_pagamento': 'Cartão'}, {'tutor': 'Karen', 'animal': 'Cachorro', 'nome_pet': 'Thor29', 'servico': 'Cirurgia', 'valor': 780, 'cidade': 'Pompeia', 'data': Timestamp('2026-03-03 00:00:00'), 'forma_pagamento': 'Cartão'}]}

# %%
colecao_relatorios.insert_one(relatorio)

print("\nRelatório salvo na coleção 'relatorios' com sucesso!")
# Out:
# Relatório salvo na coleção 'relatorios' com sucesso!
